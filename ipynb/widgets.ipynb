# %% [markdown]
# ###### Load Dependencies

# %%
from boogr import *

# %% [markdown]
# #### 📁Folder Dialog

# %%
fd = FolderDialog( )
fd.show( )

# %% [markdown]
# #### 💾 Save File Dialog

# %%
sd = SaveFileDialog( )
sd.show( )

# %% [markdown]
# #### 🔍 Google Search

# %%
google = GoogleDialog( )
google.show( )

# %% [markdown]
# #### ✨ Notification

# %%
msg = 'You were notified behind the scenes!'
notify = Notification( message=msg )
notify.show( )
# Out:
# '__MESSAGE_CLICKED__'

# %% [markdown]
# #### 📜 PDF Form

# %%
pdf = PdfForm( )
pdf.show( )

# %% [markdown]
# #### 🎭 Theme Selector

# %%
theme = ThemeSelector( )
theme.show( )

# %% [markdown]
# #### 📝 Input Dialog

# %%
input = InputDialog( )
input.show( )

# %% [markdown]
# #### 💻 Input Window

# %%
bar = InputWindow( )
bar.show( )
# Out:
# None {'-WEBSITES-': None, '-SOFTWARE-': None, '-ACCOUNT-IN-': None, '-USERID-IN-': None, '-PW-IN-': None, '-LOC-IN-': None, '-NOTES-': None, '-ACCT-LIST-': None}

# %% [markdown]
# #### 🗃️ Contact Form

# %%
contact = ContactForm( )
contact.show( )

# %% [markdown]
# #### 🔍 File Browser

# %%
file_browser = FileBrowser( )
file_browser.show( )

# %% [markdown]
# #### 💻 Email Dialog

# %%
email = EmailDialog( )
email.show( )

# %% [markdown]
# #### 🧾 Message Dialog

# %%
message_dialog = MessageDialog( )
message_dialog.show( )

# %% [markdown]
# #### 🌀 Error Dialog

# %%
ex = Exception( )
err = Error( ex )
err.heading = 'This is a heading!'
err.module = 'Testing'
err.info = 'This is only a testQ!'
error_dialog = ErrorDialog( err )
error_dialog.show( )

# %% [markdown]
# #### 📈 Scrolling Dialog

# %%
scroller = ScrollingDialog( )
scroller.show( )

# %% [markdown]
# #### 🖼️ Grid Form

# %%
grid = GridForm( )
grid.show( )

# %% [markdown]
# #### ⚙️ Loading Panel

# %%
loading = LoadingPanel( )
loading.show( )

# %% [markdown]
# #### 🧪 Waiting Panel

# %%
waiting = WaitingPanel( )
waiting.show( )

# %% [markdown]
# #### 📉 Processing Panel

# %%
processing = ProcessingPanel( )
processing.show( )

# %% [markdown]
# #### ✨ Splash Panel

# %%
splash = SplashPanel( )
splash.show( )

# %% [markdown]
# #### 💻 Calendar Dialog

# %%
calendar = CalendarDialog( )
calendar.show( )

# %% [markdown]
# #### 🗃️ ComboBox Dialog

# %%
combo = ComboBoxDialog( )
combo.show( )

# %% [markdown]
# #### 🗃️ ListBox Dialog

# %%
list = ListBoxDialog( )
list.show( )

# %% [markdown]
# #### 🎨 Color Dialog

# %%
color = ColorDialog( )
color.show( )

# %% [markdown]
# #### 🧠 Budget Form

# %%
budget = BudgetForm( )
budget.show( )
# Out:
# Exit [None]

# %% [markdown]
# #### 📊 Chart Panel

# %%
chart = ChartPanel( )
chart.show( )

# %% [markdown]
# #### 📈 CSV Form

# %%
csv = CsvForm( )
csv.show( )

# %% [markdown]
# #### 🧮 Excel Form

# %%
excel = ExcelForm( )
excel.show( )

# %% [markdown]
# #### 📈 Graph Form

# %%
graph = GraphForm( )
graph.show( )

# %% [markdown]
# #### 🧠 Chat Window

# %%
chat = ChatWindow( )
chat.show( )

# %% [markdown]
# #### 🤖 Chat Bot

# %%
bot = ChatBot( )
bot.show( )

# %% [markdown]
# #### 🌍 URL Image Viewer

# %%
image = UrlImageViewer( )
image.show( )

# %% [markdown]
# #### ⚙️ Auto Complete

# %%
auto = AutoComplete( )
auto.show( )

# %% [markdown]
# #### ✅ CheckBox

# %%
check = CheckBox( )
check.show( )

# %% [markdown]
# #### 🧠 Machine Learning Window

# %%
mlw = ParameterWindow( )
mlw.show( )

# %% [markdown]
# #### 📊 Bar Graph

# %%
bar = BarGraph( )
bar.show( )

# %% [markdown]
# #### 🎨 Style Graph

# %%
style = StyleGraph( )
style.show( )

# %% [markdown]
# #### 🏗️ Web Camera

# %%
camera = WebcamWindow( )
camera.show( )

# %% [markdown]
# #### 🧮 Scatter Graph

# %%
scatter = ScatterGraph( )
scatter.show( )

# %% [markdown]
# #### 🗣️ Animated Graph

# %%
animation = AnimatedGraph( )
animation.show( )

# %% [markdown]
# #### Data Entry Dialog

# %%
de = DataEntryDialog( )
de.show( )

# %% [markdown]
# #### Spinner Combo Dialog

# %%
spinner = SpinnerComboDialog( )
spinner.show( )

# %% [markdown]
# #### Slider Combo Dialog

# %%
slider = SliderComboDialog( )
slider.show( )
